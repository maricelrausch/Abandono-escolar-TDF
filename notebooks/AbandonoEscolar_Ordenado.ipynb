# %% [markdown]
# # 📘 Proyecto: Análisis del Abandono Escolar en TDF
#
# Este cuaderno aplica técnicas de Aprendizaje Automático para analizar el abandono escolar en Tierra del Fuego. Utiliza datos reales del sistema educativo local.
#
# ---

# %% [markdown]
# ## 📥 Carga de Datos

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

# Ruta base donde están tus archivos
base_path = 'C:/Users/maric/OneDrive/Documentos/Aprendizaje automático/Docs abandono escolar/DATA/'

# ✅ 1. Dataset de PROMOCIÓN, SOBREEDAD y ABANDONO
promocion_df = pd.read_excel(base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx')

# ✅ 2. Dataset de MATRÍCULA
matricula_df = pd.read_excel(base_path + '04-1-09-Secundario-comun.-Matricula-por-sector-de-gestion-ano-de-estudio-y-departamento.-TDF-USH-RGA-y-AA.xlsx')

# ✅ 3. Dataset de REPITENTES
repitentes_df = pd.read_excel(base_path + '04-1-10-Secundario-comun.-Repitentes-por-sector-de-gestion-y-ano-de-estudio.-2008-2021.xlsx')

# Verificar contenido
print("✔️ Datos cargados correctamente")
print("promocion_df →", promocion_df.shape)
print("matricula_df →", matricula_df.shape)
print("repitentes_df →", repitentes_df.shape)
# Out:
# ✔️ Datos cargados correctamente
# promocion_df → (9, 1)
# matricula_df → (38, 18)
# repitentes_df → (28, 27)

# %%
repitentes_df.head(15)
# Out:
#    Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021  \
# 0                                                 NaN
# 1                                                 Año
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                2008
# 7                                                2009
# 8                                                2010
# 9                                                2011
# 10                                               2012
# 11                                               2013
# 12                                               2014
# 13                                               2015
# 14                                               2016
#
#           Unnamed: 1      Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                NaN             NaN             NaN         NaN
# 1   Total provincial             NaN             NaN         NaN
# 2              Total  Sector estatal  Sector privado         NaN
# 3                NaN             NaN             NaN         NaN
# 4                NaN               %             NaN         NaN
# 5                NaN             NaN             NaN         NaN
# 6              14.61           18.86             2.5         NaN
# 7              13.38           16.81            3.46         NaN
# 8              13.76           17.51            3.16         NaN
# 9              14.33           19.28            1.38         NaN
# 10                10            13.1            2.19         NaN
# 11             10.45           13.53            2.47         NaN
# 12              9.71           12.72            1.81         NaN
# 13              7.81           10.37            1.06         NaN
# 14              7.74           10.27            1.17         NaN
#
#         Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0              NaN        NaN        NaN        NaN        NaN  ...
# 1              NaN        NaN        NaN        NaN        NaN  ...
# 2   Año de estudio        NaN        NaN        NaN        NaN  ...
# 3               1°         2°         3°         4°         5°  ...
# 4              NaN        NaN        NaN        NaN        NaN  ...
# 5              NaN        NaN        NaN        NaN        NaN  ...
# 6            18.19      18.77      15.88       16.2       9.24  ...
# 7            18.63      17.73      15.11      10.57       8.06  ...
# 8            18.52      19.49      13.43      13.03        8.7  ...
# 9            19.39      22.02      13.79      13.15       7.05  ...
# 10           13.47      16.11       9.84       7.73       5.46  ...
# 11           10.02      17.18      14.23       7.57       6.12  ...
# 12           12.13      16.04      10.73       8.76       4.84  ...
# 13            8.44      12.53       8.82       7.22       6.15  ...
# 14            7.59      12.03       9.17       8.09       5.54  ...
#
#    Unnamed: 17  Unnamed: 18 Unnamed: 19              Unnamed: 20  \
# 0          NaN          NaN         NaN                      NaN
# 1          NaN          NaN         NaN  Departamento Río Grande
# 2          NaN          NaN         NaN                    Total
# 3           5°           6°         NaN                      NaN
# 4          NaN          NaN         NaN                        %
# 5          NaN          NaN         NaN                      NaN
# 6         9.63          0.3         NaN                    14.92
# 7         9.74         0.28         NaN                    14.74
# 8        12.01          0.7         NaN                    12.33
# 9         5.49         1.51         NaN                    14.68
# 10        4.43         0.12         NaN                     9.88
# 11        4.67         1.08         NaN                    10.83
# 12        6.34            0         NaN                     9.57
# 13        5.75            0         NaN                     7.55
# 14        5.13         0.23         NaN                     8.02
#
#        Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0              NaN         NaN         NaN         NaN         NaN
# 1              NaN         NaN         NaN         NaN         NaN
# 2   Año de estudio         NaN         NaN         NaN         NaN
# 3               1°          2°          3°          4°          5°
# 4              NaN         NaN         NaN         NaN         NaN
# 5              NaN         NaN         NaN         NaN         NaN
# 6            20.78       18.54       14.83        16.3         8.9
# 7             21.5       18.94        17.4       11.45        6.67
# 8            18.61       18.59       11.86        8.54        5.59
# 9            20.17       21.59       14.74       12.08        8.53
# 10           13.73        14.6       10.32        5.97        6.36
# 11            9.87       17.45       14.01        7.95        7.43
# 12           11.72       16.05       11.88        7.34         3.6
# 13            7.39       11.38        9.37        7.07        6.47
# 14            8.03       12.51        9.45         7.6        5.87
#
#     Unnamed: 26
# 0           NaN
# 1           NaN
# 2           NaN
# 3            6°
# 4           NaN
# 5           NaN
# 6             0
# 7          0.99
# 8          0.46
# 9          0.23
# 10         0.85
# 11         3.06
# 12            0
# 13         0.09
# 14         0.95
#
# [15 rows x 27 columns]

# %%
repitentes_df_clean = repitentes_df.copy()

# Eliminar filas vacías o de encabezados textuales
repitentes_df_clean = repitentes_df_clean.drop(index=[0, 1, 2, 3, 4], errors='ignore')

# Reiniciar el índice
repitentes_df_clean.reset_index(drop=True, inplace=True)

# Visualizar resultado
repitentes_df_clean.head()
# Out:
#   Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021  \
# 0                                                NaN
# 1                                               2008
# 2                                               2009
# 3                                               2010
# 4                                               2011
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN         NaN        NaN        NaN
# 1      14.61      18.86        2.5         NaN      18.19      18.77
# 2      13.38      16.81       3.46         NaN      18.63      17.73
# 3      13.76      17.51       3.16         NaN      18.52      19.49
# 4      14.33      19.28       1.38         NaN      19.39      22.02
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 17  Unnamed: 18 Unnamed: 19  \
# 0        NaN        NaN        NaN  ...         NaN          NaN         NaN
# 1      15.88       16.2       9.24  ...        9.63          0.3         NaN
# 2      15.11      10.57       8.06  ...        9.74         0.28         NaN
# 3      13.43      13.03        8.7  ...       12.01          0.7         NaN
# 4      13.79      13.15       7.05  ...        5.49         1.51         NaN
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1       14.92       20.78       18.54       14.83        16.3         8.9
# 2       14.74        21.5       18.94        17.4       11.45        6.67
# 3       12.33       18.61       18.59       11.86        8.54        5.59
# 4       14.68       20.17       21.59       14.74       12.08        8.53
#
#    Unnamed: 26
# 0          NaN
# 1            0
# 2         0.99
# 3         0.46
# 4         0.23
#
# [5 rows x 27 columns]

# %%
repitentes_df_clean.columns
# Out:
# Index(['Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
repitentes_df_clean.columns.tolist()
# Out:
# ['Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26']

# %%
repitentes_df_clean = repitentes_df_clean.dropna(axis=1, how='all')

# %%
repitentes_df_clean.columns
# Out:
# Index(['Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26'],
#       dtype='object')

# %%
repitentes_path = "C:/Users/maric/OneDrive/Documentos/Aprendizaje automático/Docs abandono escolar/DATA/04-1-10-Secundario-comun.-Repitentes-por-sector-de-gestion-y-ano-de-estudio.-2008-2021.xlsx"

# %%
pd.ExcelFile(repitentes_path).sheet_names
# Out:
# ['04_1_10', 'Ficha técnica']

# %%
import pandas as pd

# Ruta al archivo
repitentes_path = "C:/Users/maric/OneDrive/Documentos/Aprendizaje automático/Docs abandono escolar/DATA/04-1-10-Secundario-comun.-Repitentes-por-sector-de-gestion-y-ano-de-estudio.-2008-2021.xlsx"

# Cargar la hoja correcta
repitentes_df = pd.read_excel(repitentes_path, sheet_name='04_1_10')

# Ver las primeras filas
repitentes_df.head(10)
# Out:
#   Secundario común. Repitentes por sector de gestión y año de estudio según departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2008-2021  \
# 0                                                NaN
# 1                                                Año
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                               2008
# 7                                               2009
# 8                                               2010
# 9                                               2011
#
#          Unnamed: 1      Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0               NaN             NaN             NaN         NaN
# 1  Total provincial             NaN             NaN         NaN
# 2             Total  Sector estatal  Sector privado         NaN
# 3               NaN             NaN             NaN         NaN
# 4               NaN               %             NaN         NaN
# 5               NaN             NaN             NaN         NaN
# 6             14.61           18.86             2.5         NaN
# 7             13.38           16.81            3.46         NaN
# 8             13.76           17.51            3.16         NaN
# 9             14.33           19.28            1.38         NaN
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0             NaN        NaN        NaN        NaN        NaN  ...
# 1             NaN        NaN        NaN        NaN        NaN  ...
# 2  Año de estudio        NaN        NaN        NaN        NaN  ...
# 3              1°         2°         3°         4°         5°  ...
# 4             NaN        NaN        NaN        NaN        NaN  ...
# 5             NaN        NaN        NaN        NaN        NaN  ...
# 6           18.19      18.77      15.88       16.2       9.24  ...
# 7           18.63      17.73      15.11      10.57       8.06  ...
# 8           18.52      19.49      13.43      13.03        8.7  ...
# 9           19.39      22.02      13.79      13.15       7.05  ...
#
#   Unnamed: 17  Unnamed: 18 Unnamed: 19              Unnamed: 20  \
# 0         NaN          NaN         NaN                      NaN
# 1         NaN          NaN         NaN  Departamento Río Grande
# 2         NaN          NaN         NaN                    Total
# 3          5°           6°         NaN                      NaN
# 4         NaN          NaN         NaN                        %
# 5         NaN          NaN         NaN                      NaN
# 6        9.63          0.3         NaN                    14.92
# 7        9.74         0.28         NaN                    14.74
# 8       12.01          0.7         NaN                    12.33
# 9        5.49         1.51         NaN                    14.68
#
#       Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  Unnamed: 26
# 0             NaN         NaN         NaN         NaN         NaN          NaN
# 1             NaN         NaN         NaN         NaN         NaN          NaN
# 2  Año de estudio         NaN         NaN         NaN         NaN          NaN
# 3              1°          2°          3°          4°          5°           6°
# 4             NaN         NaN         NaN         NaN         NaN          NaN
# 5             NaN         NaN         NaN         NaN         NaN          NaN
# 6           20.78       18.54       14.83        16.3         8.9            0
# 7            21.5       18.94        17.4       11.45        6.67         0.99
# 8           18.61       18.59       11.86        8.54        5.59         0.46
# 9           20.17       21.59       14.74       12.08        8.53         0.23
#
# [10 rows x 27 columns]

# %%
repitentes_df = pd.read_excel(repitentes_path, sheet_name='04_1_10', skiprows=5)

# %%
repitentes_df.head()
# Out:
#   Unnamed: 0 Unnamed: 1      %  Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0        NaN        NaN    NaN         NaN         NaN        NaN         NaN
# 1       2008      14.61  18.86        2.50         NaN      18.19       18.77
# 2       2009      13.38  16.81        3.46         NaN      18.63       17.73
# 3       2010      13.76  17.51        3.16         NaN      18.52       19.49
# 4       2011      14.33  19.28        1.38         NaN      19.39       22.02
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 17  Unnamed: 18  \
# 0         NaN         NaN         NaN  ...          NaN          NaN
# 1       15.88       16.20        9.24  ...         9.63         0.30
# 2       15.11       10.57        8.06  ...         9.74         0.28
# 3       13.43       13.03        8.70  ...        12.01         0.70
# 4       13.79       13.15        7.05  ...         5.49         1.51
#
#   Unnamed: 19    %.2  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0         NaN    NaN          NaN          NaN          NaN          NaN
# 1         NaN  14.92        20.78        18.54        14.83        16.30
# 2         NaN  14.74        21.50        18.94        17.40        11.45
# 3         NaN  12.33        18.61        18.59        11.86         8.54
# 4         NaN  14.68        20.17        21.59        14.74        12.08
#
#    Unnamed: 25  Unnamed: 26
# 0          NaN          NaN
# 1         8.90         0.00
# 2         6.67         0.99
# 3         5.59         0.46
# 4         8.53         0.23
#
# [5 rows x 27 columns]

# %%
import pandas as pd

# Ruta al archivo
repitentes_path = "C:/Users/maric/OneDrive/Documentos/Aprendizaje automático/Docs abandono escolar/DATA/04-1-10-Secundario-comun.-Repitentes-por-sector-de-gestion-y-ano-de-estudio.-2008-2021.xlsx"

# Leer la hoja correcta, salteando encabezados largos
repitentes_df = pd.read_excel(repitentes_path, sheet_name='04_1_10', skiprows=6)

# Eliminar columnas vacías (separadoras visuales del Excel)
repitentes_df = repitentes_df.dropna(axis=1, how='all')

# Verificar cuántas columnas reales quedan
print(f"Columnas reales: {len(repitentes_df.columns)}")

# Renombrar columnas según la estructura de la imagen
repitentes_df.columns = [
    "Año",
    "Porc_Total",
    "Porc_Estatal",
    "Porc_Privado",
    "1º Año",
    "2º Año",
    "3º Año",
    "4º Año",
    "5º Año",
    "6º Año",
    "Ush_Total",
    "1º Año USH",
    "2º Año USH",
    "3º Año USH ",
    "4º Año USH",
    "5º Año USH",
    "6º Año USH",
    "RG_Total",
    "1º Año RG ",
    "2º Año RG",
    "3º Año RG",
    "4º Año RG",
    "5º Año RG",
    "6º Año RG"
]

# Convertir todas las columnas (menos Año) a numérico
for col in repitentes_df.columns:
    if col != "Año":
        repitentes_df[col] = pd.to_numeric(repitentes_df[col], errors='coerce')

# Mostrar primeras filas
repitentes_df.head()
# Out:
# Columnas reales: 24
#     Año  Porc_Total  Porc_Estatal  Porc_Privado  1º Año  2º Año  3º Año  \
# 0  2008       14.61         18.86          2.50   18.19   18.77   15.88
# 1  2009       13.38         16.81          3.46   18.63   17.73   15.11
# 2  2010       13.76         17.51          3.16   18.52   19.49   13.43
# 3  2011       14.33         19.28          1.38   19.39   22.02   13.79
# 4  2012       10.00         13.10          2.19   13.47   16.11    9.84
#
#    4º Año  5º Año  6º Año  ...  4º Año USH  5º Año USH  6º Año USH  RG_Total  \
# 0   16.20    9.24    0.13  ...       16.07        9.63        0.30     14.92
# 1   10.57    8.06    0.65  ...        9.52        9.74        0.28     14.74
# 2   13.03    8.70    0.57  ...       17.69       12.01        0.70     12.33
# 3   13.15    7.05    0.81  ...       14.27        5.49        1.51     14.68
# 4    7.73    5.46    0.49  ...        9.60        4.43        0.12      9.88
#
#    1º Año RG   2º Año RG  3º Año RG  4º Año RG  5º Año RG  6º Año RG
# 0       20.78      18.54      14.83      16.30       8.90       0.00
# 1       21.50      18.94      17.40      11.45       6.67       0.99
# 2       18.61      18.59      11.86       8.54       5.59       0.46
# 3       20.17      21.59      14.74      12.08       8.53       0.23
# 4       13.73      14.60      10.32       5.97       6.36       0.85
#
# [5 rows x 24 columns]

# %%
print(len(matricula_df.columns))
matricula_df.columns.tolist()
# Out:
# 18
# ['Secundario común. Matrícula por sector de gestión, año de estudio y departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2000-2022',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17']

# %%
matricula_df = matricula_df.dropna(axis=1, how='all')

# %%
matricula_df = matricula_df.loc[:, ~matricula_df.isin(["…", ".", ""]).all()]
matricula_df.head()
# Out:
#   Secundario común. Matrícula por sector de gestión, año de estudio y departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2000-2022  \
# 0                                                NaN
# 1                                                Año
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        Unnamed: 1         Unnamed: 3 Unnamed: 4  \
# 0                             NaN                NaN        NaN
# 1  Matrícula del nivel secundario                NaN        NaN
# 2                       Matrícula  Sector de gestión        NaN
# 3                             NaN            Estatal    Privado
# 4                             NaN                NaN        NaN
#
#        Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0             NaN         NaN         NaN         NaN          NaN
# 1             NaN         NaN         NaN         NaN          NaN
# 2  Año de estudio         NaN         NaN         NaN          NaN
# 3               1         2.0         3.0         4.0          5.0
# 4             NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12   Unnamed: 14     Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN           NaN             NaN          NaN
# 1          NaN          NaN           NaN             NaN          NaN
# 2          NaN          NaN  Departamento             NaN          NaN
# 3          6.0          7.0       Ushuaia  Río Grande (1)  Tolhuin (1)
# 4          NaN          NaN           NaN             NaN          NaN
#
#            Unnamed: 17
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3  Antártida Argentina
# 4                  NaN

# %%
matricula_df.columns.tolist()
# Out:
# ['Secundario común. Matrícula por sector de gestión, año de estudio y departamento. Departamentos Ushuaia, Río Grande y Antártida Argentina, provincia de Tierra del Fuego AeIAS. Años 2000-2022',
#  'Unnamed: 1',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17']

# %%
import pandas as pd

# Cargar el archivo (ajustá la ruta si estás en local)
matricula_path = "C:/Users/maric/OneDrive/Documentos/Aprendizaje automático/Docs abandono escolar/DATA/04-1-09-Secundario-comun.-Matricula-por-sector-de-gestion-ano-de-estudio-y-departamento.-TDF-USH-RGA-y-AA.xlsx"

# Saltar las primeras 5 filas de encabezados multilínea
matricula_df = pd.read_excel(matricula_path, skiprows=5)

# Eliminar columnas completamente vacías (separadoras visuales)
matricula_df = matricula_df.dropna(axis=1, how='all')

# Renombrar columnas útiles (15 visibles)
matricula_df.columns = [
    "Año",
    "Mat_Total",
    "Mat_Estatal",
    "Mat_Privado",
    "1º Año",
    "2º Año",
    "3º Año",
    "4º Año",
    "5º Año",
    "6º Año",
    "7º Año",
    "Ushuaia",
    "RG",
    "Tolhuin",
    "Antartida"
]

# Filtrar filas válidas (años numéricos)
matricula_df = matricula_df[matricula_df["Año"].apply(lambda x: str(x).isdigit())]

# Reemplazar símbolos no numéricos como "…" o "." por NaN
matricula_df.replace(["…", ".", "… ", "-", "—"], pd.NA, inplace=True)

# Convertir columnas numéricas
for col in matricula_df.columns:
    if col != "Año":
        matricula_df[col] = pd.to_numeric(matricula_df[col], errors='coerce')

# Mostrar resultado final
matricula_df.head()
# Out:
# C:\Users\maric\AppData\Local\Temp\ipykernel_27436\2483822993.py:35: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   matricula_df.replace(["…", ".", "… ", "-", "—"], pd.NA, inplace=True)
#     Año  Mat_Total  Mat_Estatal  Mat_Privado  1º Año  2º Año  3º Año  4º Año  \
# 0  2000    10593.0       7555.0       3038.0  2131.0  2038.0  1976.0  1847.0
# 1  2001    12357.0       9191.0       3166.0  2760.0  2447.0  2157.0  1919.0
# 2  2002    13115.0       9996.0       3119.0  3056.0  2774.0  2207.0  1847.0
# 3  2003    13276.0      10094.0       3182.0  2926.0  2907.0  2468.0  1997.0
# 4  2004    13553.0      10247.0       3306.0  2780.0  2974.0  2692.0  1984.0
#
#    5º Año  6º Año  7º Año  Ushuaia  RG  Tolhuin  Antartida
# 0  1377.0  1224.0     0.0      NaN NaN      NaN        NaN
# 1  1648.0  1235.0   191.0      NaN NaN      NaN        NaN
# 2  1617.0  1384.0   230.0      NaN NaN      NaN        NaN
# 3  1599.0  1379.0     0.0      NaN NaN      NaN        NaN
# 4  1769.0  1354.0     0.0      NaN NaN      NaN        NaN

# %%
# Mostrar primeros registros de cada dataset

print("📊 PROMOCIÓN, SOBREEDAD Y ABANDONO")
display(promocion_df.head(10))

print("\n📊 MATRÍCULA")
display(matricula_df.head(10))

print("\n📊 REPITENTES")
display(repitentes_df.head(10))
# Out:
# 📊 PROMOCIÓN, SOBREEDAD Y ABANDONO
#   Secundario común. Promoción efectiva, sobreedad y abandono interanual por año de estudio. Provincia de Tierra del Fuego AeIAS.
# 0                                                NaN
# 1                                             Índice
# 2                                                NaN
# 3             Tasa de promoción efectiva y sobreedad
# 4                         Tasa de abandono internual
# 5                                      Ficha técnica
# 6                                                NaN
# 7                             Signos convencionales
# 8                    … Dato no disponible a la fecha
# 📊 MATRÍCULA
#     Año  Mat_Total  Mat_Estatal  Mat_Privado  1º Año  2º Año  3º Año  4º Año  \
# 0  2000    10593.0       7555.0       3038.0  2131.0  2038.0  1976.0  1847.0
# 1  2001    12357.0       9191.0       3166.0  2760.0  2447.0  2157.0  1919.0
# 2  2002    13115.0       9996.0       3119.0  3056.0  2774.0  2207.0  1847.0
# 3  2003    13276.0      10094.0       3182.0  2926.0  2907.0  2468.0  1997.0
# 4  2004    13553.0      10247.0       3306.0  2780.0  2974.0  2692.0  1984.0
# 5  2005    13980.0      10551.0       3429.0  2910.0  2986.0  2857.0  2083.0
# 6  2006    14281.0      10707.0       3574.0  3123.0  2942.0  2836.0  2189.0
# 7  2007    14383.0      10628.0       3755.0  3184.0  3044.0  2598.0  2226.0
# 8  2008    14762.0      10925.0       3837.0  3392.0  3111.0  2544.0  2321.0
# 9  2009    14996.0      11149.0       3847.0  3366.0  3176.0  2680.0  2385.0
#
#    5º Año  6º Año  7º Año  Ushuaia      RG  Tolhuin  Antartida
# 0  1377.0  1224.0     0.0      NaN     NaN      NaN        NaN
# 1  1648.0  1235.0   191.0      NaN     NaN      NaN        NaN
# 2  1617.0  1384.0   230.0      NaN     NaN      NaN        NaN
# 3  1599.0  1379.0     0.0      NaN     NaN      NaN        NaN
# 4  1769.0  1354.0     0.0      NaN     NaN      NaN        NaN
# 5  1737.0  1407.0     0.0      NaN     NaN      NaN        NaN
# 6  1796.0  1395.0     0.0      NaN     NaN      NaN        NaN
# 7  1849.0  1482.0     0.0      NaN     NaN      NaN        NaN
# 8  1872.0  1522.0     0.0      NaN     NaN      NaN        NaN
# 9  1862.0  1527.0     0.0   6920.0  8076.0      NaN        0.0
# 📊 REPITENTES
#     Año  Porc_Total  Porc_Estatal  Porc_Privado  1º Año  2º Año  3º Año  \
# 0  2008       14.61         18.86          2.50   18.19   18.77   15.88
# 1  2009       13.38         16.81          3.46   18.63   17.73   15.11
# 2  2010       13.76         17.51          3.16   18.52   19.49   13.43
# 3  2011       14.33         19.28          1.38   19.39   22.02   13.79
# 4  2012       10.00         13.10          2.19   13.47   16.11    9.84
# 5  2013       10.45         13.53          2.47   10.02   17.18   14.23
# 6  2014        9.71         12.72          1.81   12.13   16.04   10.73
# 7  2015        7.81         10.37          1.06    8.44   12.53    8.82
# 8  2016        7.74         10.27          1.17    7.59   12.03    9.17
# 9  2017        7.16          9.51          0.73    6.18   11.04    8.65
#
#    4º Año  5º Año  6º Año  ...  4º Año USH  5º Año USH  6º Año USH  RG_Total  \
# 0   16.20    9.24    0.13  ...       16.07        9.63        0.30     14.92
# 1   10.57    8.06    0.65  ...        9.52        9.74        0.28     14.74
# 2   13.03    8.70    0.57  ...       17.69       12.01        0.70     12.33
# 3   13.15    7.05    0.81  ...       14.27        5.49        1.51     14.68
# 4    7.73    5.46    0.49  ...        9.60        4.43        0.12      9.88
# 5    7.57    6.12    2.15  ...        7.12        4.67        1.08     10.83
# 6    8.76    4.84    0.00  ...       10.57        6.34        0.00      9.57
# 7    7.22    6.15    0.05  ...        7.41        5.75        0.00      7.55
# 8    8.09    5.54    0.62  ...        8.70        5.13        0.23      8.02
# 9    8.10    5.65    0.68  ...        9.21        7.85        0.73      6.27
#
#    1º Año RG   2º Año RG  3º Año RG  4º Año RG  5º Año RG  6º Año RG
# 0       20.78      18.54      14.83      16.30       8.90       0.00
# 1       21.50      18.94      17.40      11.45       6.67       0.99
# 2       18.61      18.59      11.86       8.54       5.59       0.46
# 3       20.17      21.59      14.74      12.08       8.53       0.23
# 4       13.73      14.60      10.32       5.97       6.36       0.85
# 5        9.87      17.45      14.01       7.95       7.43       3.06
# 6       11.72      16.05      11.88       7.34       3.60       0.00
# 7        7.39      11.38       9.37       7.07       6.47       0.09
# 8        8.03      12.51       9.45       7.60       5.87       0.95
# 9        5.44       9.79       8.16       7.24       3.87       0.63
#
# [10 rows x 24 columns]

# %%
# Cargar más abajo en la misma hoja
promocion_df_alt = pd.read_excel(base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx', skiprows=15)

# Ver las primeras filas para ver si hay tabla útil
promocion_df_alt.head(15)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.ExcelFile(base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx').sheet_names
# Out:
# ['Índice', 'cuadro 1', 'cuadro 2', 'Ficha técnica']

# %%
# Cargar hoja de promoción efectiva y sobreedad
cuadro1_df = pd.read_excel(
    base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx',
    sheet_name='cuadro 1',
    skiprows=4  # si ves texto antes, podés ajustar este número
)

# Cargar hoja de abandono interanual
cuadro2_df = pd.read_excel(
    base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx',
    sheet_name='cuadro 2',
    skiprows=4
)

# Mostrar primeros datos
print("📊 Cuadro 1: Promoción efectiva y sobreedad")
display(cuadro1_df.head(10))

print("\n📊 Cuadro 2: Abandono interanual")
display(cuadro2_df.head(10))
# Out:
# 📊 Cuadro 1: Promoción efectiva y sobreedad
#   Unnamed: 0          % Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2010  76.531707  76.436607  73.996114  76.335312  76.531493
# 2       2011  77.000335  76.303466  73.106547  77.635059  78.420835
# 3       2012  82.157595  84.137319  77.699681   84.71434  82.324059
# 4       2013  82.612572  85.623487  75.410816  82.986627  85.153019
# 5       2014  80.939055  85.565382  76.733255  81.320949  83.095723
# 6       2015  84.067881  90.164443  82.273425  79.274966   84.35559
# 7       2016   84.30197  91.822139  81.483715  82.759796  83.896696
# 8       2017   86.38683   94.69599  83.979714  84.954561  85.881908
# 9       2018  87.396056  93.295383  87.628866  89.550781  87.289993
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8        %.1  Unnamed: 10  Unnamed: 11  \
# 0        NaN        NaN         NaN        NaN          NaN          NaN
# 1  82.243953  71.275253         NaN  41.064486    38.917604    44.170984
# 2   83.58209  70.379589         NaN  31.302524    30.765886    33.346049
# 3  88.938053  74.404398         NaN  28.470718    26.849625    30.909618
# 4  90.438059  75.233902         NaN  40.481498    37.590799    40.603526
# 5  89.675651  67.891782         NaN  37.947761    31.522426    40.775558
# 6  90.074557  70.657157         NaN  33.200721    27.241700    34.685100
# 7  88.927336  73.991727         NaN  31.157470    24.502488    32.629674
# 8  92.041078   74.17795         NaN  30.354756    23.285899    33.949881
# 9  92.044981   70.34642         NaN  26.146353    18.342821    26.440267
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15
# 0          NaN          NaN          NaN          NaN
# 1    45.178042    41.932701    38.291302    34.595960
# 2    33.388242    32.527260    27.475370    27.482014
# 3    30.325404    29.774655    27.263603    23.821734
# 4    44.427935    43.341605    41.921809    34.177215
# 5    41.726866    39.959267    37.322979    35.987749
# 6    35.807114    36.335404    34.575955    31.023943
# 7    32.333901    33.308014    33.564014    32.109617
# 8    33.086503    31.680545    30.851519    28.916828
# 9    29.817708    28.889701    27.530196    26.882217
# 📊 Cuadro 2: Abandono interanual
#   Unnamed: 0         %  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        NaN       NaN         NaN         NaN         NaN         NaN
# 1  2010/2011  9.706395    5.047127    6.509067   10.237389   10.440035
# 2  2011/2012  8.670907    4.308461    4.878049    8.575746    8.433237
# 3  2012/2013  7.840440    2.397159    6.198083    5.448354    9.942717
# 4  2013/2014  6.935864    4.358354    7.409621    2.786033    7.278743
# 5  2014/2015  9.340796    2.305749    7.226792    7.946336    8.146640
# 6  2015/2016  8.062411    1.365188    5.130568   11.935705    8.423913
# 7  2016/2017  7.959134    0.590796    6.483715    8.074957    8.013673
# 8  2017/2018  6.457296   -0.873221    4.982100    6.395153    6.018168
# 9  2018/2019  7.151342    1.771031    3.881140    4.329427    6.975895
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1    9.058157   28.156566
# 2    9.366958   28.811450
# 3    5.604720   25.106903
# 4    3.438530   22.619703
# 5    5.481955   32.108218
# 6    3.448276   29.291900
# 7    5.536332   25.387797
# 8    2.310655   25.145068
# 9    2.873803   28.960739

# %%
# Eliminar la primera fila vacía de ambos cuadros
cuadro1_df = cuadro1_df.drop(index=0).reset_index(drop=True)
cuadro2_df = cuadro2_df.drop(index=0).reset_index(drop=True)

# %%
cuadro1_df.drop(cuadro1_df.columns[8], axis=1, inplace=True)
display(cuadro1_df.head(10))
# Out:
#   Unnamed: 0          % Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       2010  76.531707  76.436607  73.996114  76.335312  76.531493
# 1       2011  77.000335  76.303466  73.106547  77.635059  78.420835
# 2       2012  82.157595  84.137319  77.699681   84.71434  82.324059
# 3       2013  82.612572  85.623487  75.410816  82.986627  85.153019
# 4       2014  80.939055  85.565382  76.733255  81.320949  83.095723
# 5       2015  84.067881  90.164443  82.273425  79.274966   84.35559
# 6       2016   84.30197  91.822139  81.483715  82.759796  83.896696
# 7       2017   86.38683   94.69599  83.979714  84.954561  85.881908
# 8       2018  87.396056  93.295383  87.628866  89.550781  87.289993
# 9       2019       88.5      95.63      89.04      88.24       88.1
#
#   Unnamed: 6 Unnamed: 7        %.1  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0  82.243953  71.275253  41.064486    38.917604    44.170984    45.178042
# 1   83.58209  70.379589  31.302524    30.765886    33.346049    33.388242
# 2  88.938053  74.404398  28.470718    26.849625    30.909618    30.325404
# 3  90.438059  75.233902  40.481498    37.590799    40.603526    44.427935
# 4  89.675651  67.891782  37.947761    31.522426    40.775558    41.726866
# 5  90.074557  70.657157  33.200721    27.241700    34.685100    35.807114
# 6  88.927336  73.991727  31.157470    24.502488    32.629674    32.333901
# 7  92.041078   74.17795  30.354756    23.285899    33.949881    33.086503
# 8  92.044981   70.34642  26.146353    18.342821    26.440267    29.817708
# 9      91.64      75.37  23.920000    14.610000    22.450000    26.580000
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15
# 0    41.932701    38.291302    34.595960
# 1    32.527260    27.475370    27.482014
# 2    29.774655    27.263603    23.821734
# 3    43.341605    41.921809    34.177215
# 4    39.959267    37.322979    35.987749
# 5    36.335404    34.575955    31.023943
# 6    33.308014    33.564014    32.109617
# 7    31.680545    30.851519    28.916828
# 8    28.889701    27.530196    26.882217
# 9    28.950000    27.670000    24.180000

# %%
# Parte A: Promoción efectiva (columnas 0 a 8 excluyendo las vacías si ya las borraste)
promocion_df_clean = cuadro1_df.iloc[:, 0:8].copy()
display(promocion_df_clean.head())
# Parte B: Sobreedad (columnas desde la columna 8 en adelante)
sobreedad_df_clean = cuadro1_df.iloc[:, 8:].copy()
display(sobreedad_df_clean.head())
# Out:
#   Unnamed: 0          % Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       2010  76.531707  76.436607  73.996114  76.335312  76.531493
# 1       2011  77.000335  76.303466  73.106547  77.635059  78.420835
# 2       2012  82.157595  84.137319  77.699681   84.71434  82.324059
# 3       2013  82.612572  85.623487  75.410816  82.986627  85.153019
# 4       2014  80.939055  85.565382  76.733255  81.320949  83.095723
#
#   Unnamed: 6 Unnamed: 7
# 0  82.243953  71.275253
# 1   83.58209  70.379589
# 2  88.938053  74.404398
# 3  90.438059  75.233902
# 4  89.675651  67.891782
#          %.1  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0  41.064486    38.917604    44.170984    45.178042    41.932701    38.291302
# 1  31.302524    30.765886    33.346049    33.388242    32.527260    27.475370
# 2  28.470718    26.849625    30.909618    30.325404    29.774655    27.263603
# 3  40.481498    37.590799    40.603526    44.427935    43.341605    41.921809
# 4  37.947761    31.522426    40.775558    41.726866    39.959267    37.322979
#
#    Unnamed: 15
# 0    34.595960
# 1    27.482014
# 2    23.821734
# 3    34.177215
# 4    35.987749

# %%
# Copiar la columna 'Año' desde promoción
sobreedad_df_clean.insert(0, "Año", promocion_df_clean["Unnamed: 0"].values)
display(sobreedad_df_clean.head())
# Out:
#     Año        %.1  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0  2010  41.064486    38.917604    44.170984    45.178042    41.932701
# 1  2011  31.302524    30.765886    33.346049    33.388242    32.527260
# 2  2012  28.470718    26.849625    30.909618    30.325404    29.774655
# 3  2013  40.481498    37.590799    40.603526    44.427935    43.341605
# 4  2014  37.947761    31.522426    40.775558    41.726866    39.959267
#
#    Unnamed: 14  Unnamed: 15
# 0    38.291302    34.595960
# 1    27.475370    27.482014
# 2    27.263603    23.821734
# 3    41.921809    34.177215
# 4    37.322979    35.987749

# %%
promocion_df_clean.columns = [
    "Año",
    "Porc_Total",
    "1° Año",
    "2° Año",
    "3° Año",
    "4° Año",
    "5° Año",
    "6° Año"
]

# %%
promocion_df_clean.head()
# Out:
#     Año Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010  76.531707  76.436607  73.996114  76.335312  76.531493  82.243953
# 1  2011  77.000335  76.303466  73.106547  77.635059  78.420835   83.58209
# 2  2012  82.157595  84.137319  77.699681   84.71434  82.324059  88.938053
# 3  2013  82.612572  85.623487  75.410816  82.986627  85.153019  90.438059
# 4  2014  80.939055  85.565382  76.733255  81.320949  83.095723  89.675651
#
#       6° Año
# 0  71.275253
# 1  70.379589
# 2  74.404398
# 3  75.233902
# 4  67.891782

# %%
sobreedad_df_clean.columns = [
    "Año",
    "Porc_Total",
    "1° Año",
    "2° Año",
    "3° Año",
    "4° Año",
    "5° Año",
    "6° Año"
]
sobreedad_df_clean.head()
# Out:
#     Año  Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010   41.064486  38.917604  44.170984  45.178042  41.932701  38.291302
# 1  2011   31.302524  30.765886  33.346049  33.388242  32.527260  27.475370
# 2  2012   28.470718  26.849625  30.909618  30.325404  29.774655  27.263603
# 3  2013   40.481498  37.590799  40.603526  44.427935  43.341605  41.921809
# 4  2014   37.947761  31.522426  40.775558  41.726866  39.959267  37.322979
#
#       6° Año
# 0  34.595960
# 1  27.482014
# 2  23.821734
# 3  34.177215
# 4  35.987749

# %%
cuadro2_df.head()
# Out:
#   Unnamed: 0         %  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  2010/2011  9.706395    5.047127    6.509067   10.237389   10.440035
# 1  2011/2012  8.670907    4.308461    4.878049    8.575746    8.433237
# 2  2012/2013  7.840440    2.397159    6.198083    5.448354    9.942717
# 3  2013/2014  6.935864    4.358354    7.409621    2.786033    7.278743
# 4  2014/2015  9.340796    2.305749    7.226792    7.946336    8.146640
#
#    Unnamed: 6  Unnamed: 7
# 0    9.058157   28.156566
# 1    9.366958   28.811450
# 2    5.604720   25.106903
# 3    3.438530   22.619703
# 4    5.481955   32.108218

# %%
cuadro2_df.columns = [
    "Año",
    "Porc_Total",
    "1° Año",
    "2° Año",
    "3° Año",
    "4° Año",
    "5° Año",
    "6° Año"
]
sobreedad_df_clean.head()
# Out:
#     Año  Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010   41.064486  38.917604  44.170984  45.178042  41.932701  38.291302
# 1  2011   31.302524  30.765886  33.346049  33.388242  32.527260  27.475370
# 2  2012   28.470718  26.849625  30.909618  30.325404  29.774655  27.263603
# 3  2013   40.481498  37.590799  40.603526  44.427935  43.341605  41.921809
# 4  2014   37.947761  31.522426  40.775558  41.726866  39.959267  37.322979
#
#       6° Año
# 0  34.595960
# 1  27.482014
# 2  23.821734
# 3  34.177215
# 4  35.987749

# %%
abandono_df = cuadro2_df.copy()

# %%
# 1. Cargar la hoja "cuadro 2" con abandono interanual
abandono_df = pd.read_excel(
    base_path + '04_01_06-Secundario-comun.-Promocion-efectiva-sobreedad-y-abandono-interanual-por-ano-de-estudio.-TDF.xlsx',
    sheet_name='cuadro 2',
    skiprows=4
)

# 2. Eliminar la primera fila si está vacía
abandono_df = abandono_df.drop(index=0).reset_index(drop=True)

# 3. Eliminar columnas completamente vacías (separadoras visuales)
abandono_df = abandono_df.dropna(axis=1, how='all')

# 4. Renombrar columnas
abandono_df.columns = [
    "Año",
    "Porc_Total",
    "1° Año",
    "2° Año",
    "3° Año",
    "4° Año",
    "5° Año",
    "6° Año"
]

# 5. Reemplazar valores no válidos
abandono_df.replace(["…", ".", "-", "—"], pd.NA, inplace=True)

# 6. Convertir columnas numéricas (excepto Año)
for col in abandono_df.columns:
    if col != "Año":
        abandono_df[col] = pd.to_numeric(abandono_df[col], errors='coerce')

# 7. Redondear a 2 decimales
for col in abandono_df.columns:
    if col != "Año":
        abandono_df[col] = abandono_df[col].round(2)

# 8. Verificar resultado
display(abandono_df.head())
# Out:
#          Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010/2011        9.71    5.05    6.51   10.24   10.44    9.06   28.16
# 1  2011/2012        8.67    4.31    4.88    8.58    8.43    9.37   28.81
# 2  2012/2013        7.84    2.40    6.20    5.45    9.94    5.60   25.11
# 3  2013/2014        6.94    4.36    7.41    2.79    7.28    3.44   22.62
# 4  2014/2015        9.34    2.31    7.23    7.95    8.15    5.48   32.11

# %%
# Asegurarse de que todas las columnas "Año" sean string y sin espacios
for df in [promocion_df_clean, sobreedad_df_clean, abandono_df]:
    df["Año"] = df["Año"].astype(str).str.strip()

# %%
print("📊 Promoción efectiva")
display(promocion_df_clean.head(10))

print("📊 Sobreedad")
display(sobreedad_df_clean.head(10))

print("📊 Abandono interanual")
display(abandono_df.head(10))

print("📊 Repitentes")
display(repitentes_df.head(10))

print("📊 Matrícula")
display(matricula_df.head(10))
# Out:
# 📊 Promoción efectiva
#     Año Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010  76.531707  76.436607  73.996114  76.335312  76.531493  82.243953
# 1  2011  77.000335  76.303466  73.106547  77.635059  78.420835   83.58209
# 2  2012  82.157595  84.137319  77.699681   84.71434  82.324059  88.938053
# 3  2013  82.612572  85.623487  75.410816  82.986627  85.153019  90.438059
# 4  2014  80.939055  85.565382  76.733255  81.320949  83.095723  89.675651
# 5  2015  84.067881  90.164443  82.273425  79.274966   84.35559  90.074557
# 6  2016   84.30197  91.822139  81.483715  82.759796  83.896696  88.927336
# 7  2017   86.38683   94.69599  83.979714  84.954561  85.881908  92.041078
# 8  2018  87.396056  93.295383  87.628866  89.550781  87.289993  92.044981
# 9  2019       88.5      95.63      89.04      88.24       88.1      91.64
#
#       6° Año
# 0  71.275253
# 1  70.379589
# 2  74.404398
# 3  75.233902
# 4  67.891782
# 5  70.657157
# 6  73.991727
# 7   74.17795
# 8   70.34642
# 9      75.37
# 📊 Sobreedad
#     Año  Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010   41.064486  38.917604  44.170984  45.178042  41.932701  38.291302
# 1  2011   31.302524  30.765886  33.346049  33.388242  32.527260  27.475370
# 2  2012   28.470718  26.849625  30.909618  30.325404  29.774655  27.263603
# 3  2013   40.481498  37.590799  40.603526  44.427935  43.341605  41.921809
# 4  2014   37.947761  31.522426  40.775558  41.726866  39.959267  37.322979
# 5  2015   33.200721  27.241700  34.685100  35.807114  36.335404  34.575955
# 6  2016   31.157470  24.502488  32.629674  32.333901  33.308014  33.564014
# 7  2017   30.354756  23.285899  33.949881  33.086503  31.680545  30.851519
# 8  2018   26.146353  18.342821  26.440267  29.817708  28.889701  27.530196
# 9  2019   23.920000  14.610000  22.450000  26.580000  28.950000  27.670000
#
#       6° Año
# 0  34.595960
# 1  27.482014
# 2  23.821734
# 3  34.177215
# 4  35.987749
# 5  31.023943
# 6  32.109617
# 7  28.916828
# 8  26.882217
# 9  24.180000
# 📊 Abandono interanual
#          Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010/2011        9.71    5.05    6.51   10.24   10.44    9.06   28.16
# 1  2011/2012        8.67    4.31    4.88    8.58    8.43    9.37   28.81
# 2  2012/2013        7.84    2.40    6.20    5.45    9.94    5.60   25.11
# 3  2013/2014        6.94    4.36    7.41    2.79    7.28    3.44   22.62
# 4  2014/2015        9.34    2.31    7.23    7.95    8.15    5.48   32.11
# 5  2015/2016        8.06    1.37    5.13   11.94    8.42    3.45   29.29
# 6  2016/2017        7.96    0.59    6.48    8.07    8.01    5.54   25.39
# 7  2017/2018        6.46   -0.87    4.98    6.40    6.02    2.31   25.15
# 8  2018/2019        7.15    1.77    3.88    4.33    6.98    2.87   28.96
# 9  2019/2020        5.55   -0.66    3.53    4.74    5.16    1.23   23.42
# 📊 Repitentes
#     Año  Porc_Total  Porc_Estatal  Porc_Privado  1º Año  2º Año  3º Año  \
# 0  2008       14.61         18.86          2.50   18.19   18.77   15.88
# 1  2009       13.38         16.81          3.46   18.63   17.73   15.11
# 2  2010       13.76         17.51          3.16   18.52   19.49   13.43
# 3  2011       14.33         19.28          1.38   19.39   22.02   13.79
# 4  2012       10.00         13.10          2.19   13.47   16.11    9.84
# 5  2013       10.45         13.53          2.47   10.02   17.18   14.23
# 6  2014        9.71         12.72          1.81   12.13   16.04   10.73
# 7  2015        7.81         10.37          1.06    8.44   12.53    8.82
# 8  2016        7.74         10.27          1.17    7.59   12.03    9.17
# 9  2017        7.16          9.51          0.73    6.18   11.04    8.65
#
#    4º Año  5º Año  6º Año  ...  4º Año USH  5º Año USH  6º Año USH  RG_Total  \
# 0   16.20    9.24    0.13  ...       16.07        9.63        0.30     14.92
# 1   10.57    8.06    0.65  ...        9.52        9.74        0.28     14.74
# 2   13.03    8.70    0.57  ...       17.69       12.01        0.70     12.33
# 3   13.15    7.05    0.81  ...       14.27        5.49        1.51     14.68
# 4    7.73    5.46    0.49  ...        9.60        4.43        0.12      9.88
# 5    7.57    6.12    2.15  ...        7.12        4.67        1.08     10.83
# 6    8.76    4.84    0.00  ...       10.57        6.34        0.00      9.57
# 7    7.22    6.15    0.05  ...        7.41        5.75        0.00      7.55
# 8    8.09    5.54    0.62  ...        8.70        5.13        0.23      8.02
# 9    8.10    5.65    0.68  ...        9.21        7.85        0.73      6.27
#
#    1º Año RG   2º Año RG  3º Año RG  4º Año RG  5º Año RG  6º Año RG
# 0       20.78      18.54      14.83      16.30       8.90       0.00
# 1       21.50      18.94      17.40      11.45       6.67       0.99
# 2       18.61      18.59      11.86       8.54       5.59       0.46
# 3       20.17      21.59      14.74      12.08       8.53       0.23
# 4       13.73      14.60      10.32       5.97       6.36       0.85
# 5        9.87      17.45      14.01       7.95       7.43       3.06
# 6       11.72      16.05      11.88       7.34       3.60       0.00
# 7        7.39      11.38       9.37       7.07       6.47       0.09
# 8        8.03      12.51       9.45       7.60       5.87       0.95
# 9        5.44       9.79       8.16       7.24       3.87       0.63
#
# [10 rows x 24 columns]
# 📊 Matrícula
#     Año  Mat_Total  Mat_Estatal  Mat_Privado  1º Año  2º Año  3º Año  4º Año  \
# 0  2000    10593.0       7555.0       3038.0  2131.0  2038.0  1976.0  1847.0
# 1  2001    12357.0       9191.0       3166.0  2760.0  2447.0  2157.0  1919.0
# 2  2002    13115.0       9996.0       3119.0  3056.0  2774.0  2207.0  1847.0
# 3  2003    13276.0      10094.0       3182.0  2926.0  2907.0  2468.0  1997.0
# 4  2004    13553.0      10247.0       3306.0  2780.0  2974.0  2692.0  1984.0
# 5  2005    13980.0      10551.0       3429.0  2910.0  2986.0  2857.0  2083.0
# 6  2006    14281.0      10707.0       3574.0  3123.0  2942.0  2836.0  2189.0
# 7  2007    14383.0      10628.0       3755.0  3184.0  3044.0  2598.0  2226.0
# 8  2008    14762.0      10925.0       3837.0  3392.0  3111.0  2544.0  2321.0
# 9  2009    14996.0      11149.0       3847.0  3366.0  3176.0  2680.0  2385.0
#
#    5º Año  6º Año  7º Año  Ushuaia      RG  Tolhuin  Antartida
# 0  1377.0  1224.0     0.0      NaN     NaN      NaN        NaN
# 1  1648.0  1235.0   191.0      NaN     NaN      NaN        NaN
# 2  1617.0  1384.0   230.0      NaN     NaN      NaN        NaN
# 3  1599.0  1379.0     0.0      NaN     NaN      NaN        NaN
# 4  1769.0  1354.0     0.0      NaN     NaN      NaN        NaN
# 5  1737.0  1407.0     0.0      NaN     NaN      NaN        NaN
# 6  1796.0  1395.0     0.0      NaN     NaN      NaN        NaN
# 7  1849.0  1482.0     0.0      NaN     NaN      NaN        NaN
# 8  1872.0  1522.0     0.0      NaN     NaN      NaN        NaN
# 9  1862.0  1527.0     0.0   6920.0  8076.0      NaN        0.0

# %%
def limpiar_columna_anio(df):
    df = df.copy()
    df["Año"] = (
        df["Año"]
        .astype(str)
        .str.replace(r"\s+", "", regex=True)
        .str.replace(u"\xa0", "", regex=False)
        .str.strip()
    )
    df = df[df["Año"].str.contains(r"^\d{4}/?\d{0,4}$", regex=True)]
    return df.reset_index(drop=True)

promocion_df_clean = limpiar_columna_anio(promocion_df_clean)
sobreedad_df_clean = limpiar_columna_anio(sobreedad_df_clean)
abandono_df = limpiar_columna_anio(abandono_df)
repitentes_df = limpiar_columna_anio(repitentes_df)
matricula_df = limpiar_columna_anio(matricula_df)

# %%
print("📊 Promoción efectiva")
display(promocion_df_clean.head(10))

print("📊 Sobreedad")
display(sobreedad_df_clean.head(10))

print("📊 Abandono interanual")
display(abandono_df.head(10))

print("📊 Repitentes")
display(repitentes_df.head(10))

print("📊 Matrícula")
display(matricula_df.head(10))
# Out:
# 📊 Promoción efectiva
#     Año Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010  76.531707  76.436607  73.996114  76.335312  76.531493  82.243953
# 1  2011  77.000335  76.303466  73.106547  77.635059  78.420835   83.58209
# 2  2012  82.157595  84.137319  77.699681   84.71434  82.324059  88.938053
# 3  2013  82.612572  85.623487  75.410816  82.986627  85.153019  90.438059
# 4  2014  80.939055  85.565382  76.733255  81.320949  83.095723  89.675651
# 5  2015  84.067881  90.164443  82.273425  79.274966   84.35559  90.074557
# 6  2016   84.30197  91.822139  81.483715  82.759796  83.896696  88.927336
# 7  2017   86.38683   94.69599  83.979714  84.954561  85.881908  92.041078
# 8  2018  87.396056  93.295383  87.628866  89.550781  87.289993  92.044981
# 9  2019       88.5      95.63      89.04      88.24       88.1      91.64
#
#       6° Año
# 0  71.275253
# 1  70.379589
# 2  74.404398
# 3  75.233902
# 4  67.891782
# 5  70.657157
# 6  73.991727
# 7   74.17795
# 8   70.34642
# 9      75.37
# 📊 Sobreedad
#     Año  Porc_Total     1° Año     2° Año     3° Año     4° Año     5° Año  \
# 0  2010   41.064486  38.917604  44.170984  45.178042  41.932701  38.291302
# 1  2011   31.302524  30.765886  33.346049  33.388242  32.527260  27.475370
# 2  2012   28.470718  26.849625  30.909618  30.325404  29.774655  27.263603
# 3  2013   40.481498  37.590799  40.603526  44.427935  43.341605  41.921809
# 4  2014   37.947761  31.522426  40.775558  41.726866  39.959267  37.322979
# 5  2015   33.200721  27.241700  34.685100  35.807114  36.335404  34.575955
# 6  2016   31.157470  24.502488  32.629674  32.333901  33.308014  33.564014
# 7  2017   30.354756  23.285899  33.949881  33.086503  31.680545  30.851519
# 8  2018   26.146353  18.342821  26.440267  29.817708  28.889701  27.530196
# 9  2019   23.920000  14.610000  22.450000  26.580000  28.950000  27.670000
#
#       6° Año
# 0  34.595960
# 1  27.482014
# 2  23.821734
# 3  34.177215
# 4  35.987749
# 5  31.023943
# 6  32.109617
# 7  28.916828
# 8  26.882217
# 9  24.180000
# 📊 Abandono interanual
#          Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010/2011        9.71    5.05    6.51   10.24   10.44    9.06   28.16
# 1  2011/2012        8.67    4.31    4.88    8.58    8.43    9.37   28.81
# 2  2012/2013        7.84    2.40    6.20    5.45    9.94    5.60   25.11
# 3  2013/2014        6.94    4.36    7.41    2.79    7.28    3.44   22.62
# 4  2014/2015        9.34    2.31    7.23    7.95    8.15    5.48   32.11
# 5  2015/2016        8.06    1.37    5.13   11.94    8.42    3.45   29.29
# 6  2016/2017        7.96    0.59    6.48    8.07    8.01    5.54   25.39
# 7  2017/2018        6.46   -0.87    4.98    6.40    6.02    2.31   25.15
# 8  2018/2019        7.15    1.77    3.88    4.33    6.98    2.87   28.96
# 9  2019/2020        5.55   -0.66    3.53    4.74    5.16    1.23   23.42
# 📊 Repitentes
#     Año  Porc_Total  Porc_Estatal  Porc_Privado  1º Año  2º Año  3º Año  \
# 0  2008       14.61         18.86          2.50   18.19   18.77   15.88
# 1  2009       13.38         16.81          3.46   18.63   17.73   15.11
# 2  2010       13.76         17.51          3.16   18.52   19.49   13.43
# 3  2011       14.33         19.28          1.38   19.39   22.02   13.79
# 4  2012       10.00         13.10          2.19   13.47   16.11    9.84
# 5  2013       10.45         13.53          2.47   10.02   17.18   14.23
# 6  2014        9.71         12.72          1.81   12.13   16.04   10.73
# 7  2015        7.81         10.37          1.06    8.44   12.53    8.82
# 8  2016        7.74         10.27          1.17    7.59   12.03    9.17
# 9  2017        7.16          9.51          0.73    6.18   11.04    8.65
#
#    4º Año  5º Año  6º Año  ...  4º Año USH  5º Año USH  6º Año USH  RG_Total  \
# 0   16.20    9.24    0.13  ...       16.07        9.63        0.30     14.92
# 1   10.57    8.06    0.65  ...        9.52        9.74        0.28     14.74
# 2   13.03    8.70    0.57  ...       17.69       12.01        0.70     12.33
# 3   13.15    7.05    0.81  ...       14.27        5.49        1.51     14.68
# 4    7.73    5.46    0.49  ...        9.60        4.43        0.12      9.88
# 5    7.57    6.12    2.15  ...        7.12        4.67        1.08     10.83
# 6    8.76    4.84    0.00  ...       10.57        6.34        0.00      9.57
# 7    7.22    6.15    0.05  ...        7.41        5.75        0.00      7.55
# 8    8.09    5.54    0.62  ...        8.70        5.13        0.23      8.02
# 9    8.10    5.65    0.68  ...        9.21        7.85        0.73      6.27
#
#    1º Año RG   2º Año RG  3º Año RG  4º Año RG  5º Año RG  6º Año RG
# 0       20.78      18.54      14.83      16.30       8.90       0.00
# 1       21.50      18.94      17.40      11.45       6.67       0.99
# 2       18.61      18.59      11.86       8.54       5.59       0.46
# 3       20.17      21.59      14.74      12.08       8.53       0.23
# 4       13.73      14.60      10.32       5.97       6.36       0.85
# 5        9.87      17.45      14.01       7.95       7.43       3.06
# 6       11.72      16.05      11.88       7.34       3.60       0.00
# 7        7.39      11.38       9.37       7.07       6.47       0.09
# 8        8.03      12.51       9.45       7.60       5.87       0.95
# 9        5.44       9.79       8.16       7.24       3.87       0.63
#
# [10 rows x 24 columns]
# 📊 Matrícula
#     Año  Mat_Total  Mat_Estatal  Mat_Privado  1º Año  2º Año  3º Año  4º Año  \
# 0  2000    10593.0       7555.0       3038.0  2131.0  2038.0  1976.0  1847.0
# 1  2001    12357.0       9191.0       3166.0  2760.0  2447.0  2157.0  1919.0
# 2  2002    13115.0       9996.0       3119.0  3056.0  2774.0  2207.0  1847.0
# 3  2003    13276.0      10094.0       3182.0  2926.0  2907.0  2468.0  1997.0
# 4  2004    13553.0      10247.0       3306.0  2780.0  2974.0  2692.0  1984.0
# 5  2005    13980.0      10551.0       3429.0  2910.0  2986.0  2857.0  2083.0
# 6  2006    14281.0      10707.0       3574.0  3123.0  2942.0  2836.0  2189.0
# 7  2007    14383.0      10628.0       3755.0  3184.0  3044.0  2598.0  2226.0
# 8  2008    14762.0      10925.0       3837.0  3392.0  3111.0  2544.0  2321.0
# 9  2009    14996.0      11149.0       3847.0  3366.0  3176.0  2680.0  2385.0
#
#    5º Año  6º Año  7º Año  Ushuaia      RG  Tolhuin  Antartida
# 0  1377.0  1224.0     0.0      NaN     NaN      NaN        NaN
# 1  1648.0  1235.0   191.0      NaN     NaN      NaN        NaN
# 2  1617.0  1384.0   230.0      NaN     NaN      NaN        NaN
# 3  1599.0  1379.0     0.0      NaN     NaN      NaN        NaN
# 4  1769.0  1354.0     0.0      NaN     NaN      NaN        NaN
# 5  1737.0  1407.0     0.0      NaN     NaN      NaN        NaN
# 6  1796.0  1395.0     0.0      NaN     NaN      NaN        NaN
# 7  1849.0  1482.0     0.0      NaN     NaN      NaN        NaN
# 8  1872.0  1522.0     0.0      NaN     NaN      NaN        NaN
# 9  1862.0  1527.0     0.0   6920.0  8076.0      NaN        0.0

# %%
print("🔎 Años en promoción_df_clean:")
print(promocion_df_clean["Año"].unique())

print("\n🔎 Años en sobreedad_df_clean:")
print(sobreedad_df_clean["Año"].unique())

print("\n🔎 Años en abandono_df:")
print(abandono_df["Año"].unique())
# Convertir a conjuntos
set_prom = set(promocion_df_clean["Año"])
set_sobre = set(sobreedad_df_clean["Año"])
set_aband = set(abandono_df["Año"])

# Intersecciones
print("🎯 Años comunes entre los tres:")
print(set_prom & set_sobre & set_aband)
# Out:
# 🔎 Años en promoción_df_clean:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
#
# 🔎 Años en sobreedad_df_clean:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
#
# 🔎 Años en abandono_df:
# ['2010/2011' '2011/2012' '2012/2013' '2013/2014' '2014/2015' '2015/2016'
#  '2016/2017' '2017/2018' '2018/2019' '2019/2020' '2020/2021' '2021/2022']
# 🎯 Años comunes entre los tres:
# set()

# %%
# Función para convertir y redondear columnas (excepto "Año")
def convertir_y_redondear(df):
    df = df.copy()
    for col in df.columns:
        if col != "Año":
            df[col] = pd.to_numeric(df[col], errors='coerce').round(2)
    return df

# Aplicar a los tres DataFrames originales
promocion_df_clean = convertir_y_redondear(promocion_df_clean)
sobreedad_df_clean = convertir_y_redondear(sobreedad_df_clean)
abandono_df = convertir_y_redondear(abandono_df)

# Mostrar para confirmar
print("📘 Promoción efectiva:")
display(promocion_df_clean.head(5))

print("📗 Sobreedad:")
display(sobreedad_df_clean.head(5))

print("📕 Abandono:")
display(abandono_df.head(5))
# Out:
# 📘 Promoción efectiva:
#     Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010       76.53   76.44   74.00   76.34   76.53   82.24   71.28
# 1  2011       77.00   76.30   73.11   77.64   78.42   83.58   70.38
# 2  2012       82.16   84.14   77.70   84.71   82.32   88.94   74.40
# 3  2013       82.61   85.62   75.41   82.99   85.15   90.44   75.23
# 4  2014       80.94   85.57   76.73   81.32   83.10   89.68   67.89
# 📗 Sobreedad:
#     Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010       41.06   38.92   44.17   45.18   41.93   38.29   34.60
# 1  2011       31.30   30.77   33.35   33.39   32.53   27.48   27.48
# 2  2012       28.47   26.85   30.91   30.33   29.77   27.26   23.82
# 3  2013       40.48   37.59   40.60   44.43   43.34   41.92   34.18
# 4  2014       37.95   31.52   40.78   41.73   39.96   37.32   35.99
# 📕 Abandono:
#          Año  Porc_Total  1° Año  2° Año  3° Año  4° Año  5° Año  6° Año
# 0  2010/2011        9.71    5.05    6.51   10.24   10.44    9.06   28.16
# 1  2011/2012        8.67    4.31    4.88    8.58    8.43    9.37   28.81
# 2  2012/2013        7.84    2.40    6.20    5.45    9.94    5.60   25.11
# 3  2013/2014        6.94    4.36    7.41    2.79    7.28    3.44   22.62
# 4  2014/2015        9.34    2.31    7.23    7.95    8.15    5.48   32.11

# %%
# Transformar columna Año en abandono_df para que coincida
abandono_df["Año"] = abandono_df["Año"].str.slice(0, 4)

# %%
print("🔎 Años en promoción_df_clean:")
print(promocion_df_clean["Año"].unique())

print("\n🔎 Años en sobreedad_df_clean:")
print(sobreedad_df_clean["Año"].unique())

print("\n🔎 Años en abandono_df:")
print(abandono_df["Año"].unique())
# Convertir a conjuntos
set_prom = set(promocion_df_clean["Año"])
set_sobre = set(sobreedad_df_clean["Año"])
set_aband = set(abandono_df["Año"])

# Intersecciones
print("🎯 Años comunes entre los tres:")
print(set_prom & set_sobre & set_aband)
# Out:
# 🔎 Años en promoción_df_clean:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
#
# 🔎 Años en sobreedad_df_clean:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021' '2022']
#
# 🔎 Años en abandono_df:
# ['2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018' '2019'
#  '2020' '2021']
# 🎯 Años comunes entre los tres:
# {'2016', '2010', '2017', '2018', '2019', '2015', '2011', '2020', '2021', '2013', '2014', '2012'}

# %% [markdown]
# ## 🧼 Limpieza y Combinación de Datos

# %%
# 1. Fusionar promoción y sobreedad
promocion_total_df = pd.merge(
    promocion_df_clean,
    sobreedad_df_clean,
    on="Año",
    suffixes=('_Promoción', '_Sobreedad')
)

# 2. Fusionar el resultado con abandono
df_final = pd.merge(
    promocion_total_df,
    abandono_df,
    on="Año"
)

# 3. Renombrar columnas de abandono con sufijo
col_abandono = abandono_df.columns.drop("Año")
nuevo_nombre = {col: col + "_Abandono" for col in col_abandono}
df_final.rename(columns=nuevo_nombre, inplace=True)

# 4. Mostrar la tabla combinada final
print("✅ Tabla final combinada (Promoción + Sobreedad + Abandono):")
display(df_final.head(10))
# Out:
# ✅ Tabla final combinada (Promoción + Sobreedad + Abandono):
#     Año  Porc_Total_Promoción  1° Año_Promoción  2° Año_Promoción  \
# 0  2010                 76.53             76.44             74.00
# 1  2011                 77.00             76.30             73.11
# 2  2012                 82.16             84.14             77.70
# 3  2013                 82.61             85.62             75.41
# 4  2014                 80.94             85.57             76.73
# 5  2015                 84.07             90.16             82.27
# 6  2016                 84.30             91.82             81.48
# 7  2017                 86.39             94.70             83.98
# 8  2018                 87.40             93.30             87.63
# 9  2019                 88.50             95.63             89.04
#
#    3° Año_Promoción  4° Año_Promoción  5° Año_Promoción  6° Año_Promoción  \
# 0             76.34             76.53             82.24             71.28
# 1             77.64             78.42             83.58             70.38
# 2             84.71             82.32             88.94             74.40
# 3             82.99             85.15             90.44             75.23
# 4             81.32             83.10             89.68             67.89
# 5             79.27             84.36             90.07             70.66
# 6             82.76             83.90             88.93             73.99
# 7             84.95             85.88             92.04             74.18
# 8             89.55             87.29             92.04             70.35
# 9             88.24             88.10             91.64             75.37
#
#    Porc_Total_Sobreedad  1° Año_Sobreedad  ...  4° Año_Sobreedad  \
# 0                 41.06             38.92  ...             41.93
# 1                 31.30             30.77  ...             32.53
# 2                 28.47             26.85  ...             29.77
# 3                 40.48             37.59  ...             43.34
# 4                 37.95             31.52  ...             39.96
# 5                 33.20             27.24  ...             36.34
# 6                 31.16             24.50  ...             33.31
# 7                 30.35             23.29  ...             31.68
# 8                 26.15             18.34  ...             28.89
# 9                 23.92             14.61  ...             28.95
#
#    5° Año_Sobreedad  6° Año_Sobreedad  Porc_Total_Abandono  1° Año_Abandono  \
# 0             38.29             34.60                 9.71             5.05
# 1             27.48             27.48                 8.67             4.31
# 2             27.26             23.82                 7.84             2.40
# 3             41.92             34.18                 6.94             4.36
# 4             37.32             35.99                 9.34             2.31
# 5             34.58             31.02                 8.06             1.37
# 6             33.56             32.11                 7.96             0.59
# 7             30.85             28.92                 6.46            -0.87
# 8             27.53             26.88                 7.15             1.77
# 9             27.67             24.18                 5.55            -0.66
#
#    2° Año_Abandono  3° Año_Abandono  4° Año_Abandono  5° Año_Abandono  \
# 0             6.51            10.24            10.44             9.06
# 1             4.88             8.58             8.43             9.37
# 2             6.20             5.45             9.94             5.60
# 3             7.41             2.79             7.28             3.44
# 4             7.23             7.95             8.15             5.48
# 5             5.13            11.94             8.42             3.45
# 6             6.48             8.07             8.01             5.54
# 7             4.98             6.40             6.02             2.31
# 8             3.88             4.33             6.98             2.87
# 9             3.53             4.74             5.16             1.23
#
#    6° Año_Abandono
# 0            28.16
# 1            28.81
# 2            25.11
# 3            22.62
# 4            32.11
# 5            29.29
# 6            25.39
# 7            25.15
# 8            28.96
# 9            23.42
#
# [10 rows x 22 columns]

# %%
# Redondear todas las columnas numéricas a 2 decimales, excepto "Año"
for col in df_final.columns:
    if col != "Año":
        df_final[col] = df_final[col].round(2)

# %%
display(df_final.head(20))
# Out:
#      Año  Porc_Total_Promoción  1° Año_Promoción  2° Año_Promoción  \
# 0   2010                 76.53             76.44             74.00
# 1   2011                 77.00             76.30             73.11
# 2   2012                 82.16             84.14             77.70
# 3   2013                 82.61             85.62             75.41
# 4   2014                 80.94             85.57             76.73
# 5   2015                 84.07             90.16             82.27
# 6   2016                 84.30             91.82             81.48
# 7   2017                 86.39             94.70             83.98
# 8   2018                 87.40             93.30             87.63
# 9   2019                 88.50             95.63             89.04
# 10  2020                 93.48            100.39             99.10
# 11  2021                   NaN               NaN               NaN
#
#     3° Año_Promoción  4° Año_Promoción  5° Año_Promoción  6° Año_Promoción  \
# 0              76.34             76.53             82.24             71.28
# 1              77.64             78.42             83.58             70.38
# 2              84.71             82.32             88.94             74.40
# 3              82.99             85.15             90.44             75.23
# 4              81.32             83.10             89.68             67.89
# 5              79.27             84.36             90.07             70.66
# 6              82.76             83.90             88.93             73.99
# 7              84.95             85.88             92.04             74.18
# 8              89.55             87.29             92.04             70.35
# 9              88.24             88.10             91.64             75.37
# 10            100.26             98.08             97.81             56.98
# 11               NaN               NaN               NaN               NaN
#
#     Porc_Total_Sobreedad  1° Año_Sobreedad  ...  4° Año_Sobreedad  \
# 0                  41.06             38.92  ...             41.93
# 1                  31.30             30.77  ...             32.53
# 2                  28.47             26.85  ...             29.77
# 3                  40.48             37.59  ...             43.34
# 4                  37.95             31.52  ...             39.96
# 5                  33.20             27.24  ...             36.34
# 6                  31.16             24.50  ...             33.31
# 7                  30.35             23.29  ...             31.68
# 8                  26.15             18.34  ...             28.89
# 9                  23.92             14.61  ...             28.95
# 10                 22.61             16.31  ...             25.69
# 11                 17.23              8.19  ...             20.35
#
#     5° Año_Sobreedad  6° Año_Sobreedad  Porc_Total_Abandono  1° Año_Abandono  \
# 0              38.29             34.60                 9.71             5.05
# 1              27.48             27.48                 8.67             4.31
# 2              27.26             23.82                 7.84             2.40
# 3              41.92             34.18                 6.94             4.36
# 4              37.32             35.99                 9.34             2.31
# 5              34.58             31.02                 8.06             1.37
# 6              33.56             32.11                 7.96             0.59
# 7              30.85             28.92                 6.46            -0.87
# 8              27.53             26.88                 7.15             1.77
# 9              27.67             24.18                 5.55            -0.66
# 10             28.31             22.33                 6.52            -0.42
# 11             23.21             24.13                 5.71            -1.23
#
#     2° Año_Abandono  3° Año_Abandono  4° Año_Abandono  5° Año_Abandono  \
# 0              6.51            10.24            10.44             9.06
# 1              4.88             8.58             8.43             9.37
# 2              6.20             5.45             9.94             5.60
# 3              7.41             2.79             7.28             3.44
# 4              7.23             7.95             8.15             5.48
# 5              5.13            11.94             8.42             3.45
# 6              6.48             8.07             8.01             5.54
# 7              4.98             6.40             6.02             2.31
# 8              3.88             4.33             6.98             2.87
# 9              3.53             4.74             5.16             1.23
# 10             0.90            -0.26             1.92             2.19
# 11             1.82             3.62             4.58             5.53
#
#     6° Año_Abandono
# 0             28.16
# 1             28.81
# 2             25.11
# 3             22.62
# 4             32.11
# 5             29.29
# 6             25.39
# 7             25.15
# 8             28.96
# 9             23.42
# 10            43.02
# 11            21.89
#
# [12 rows x 22 columns]

# %% [markdown]
# ## 🔎 Exploración Inicial

# %% [markdown]
# ## 📊 Visualización

# %% [markdown]
# ## 🧠 Modelado (por hacer)
